# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import json
import time
from bs4 import BeautifulSoup as bs
import gmaps
import locale
from census import Census
c = Census('c0e1bc0567636e35afe801464f2d1acecd3485c5', year = 2017)


api_key_census = 'c0e1bc0567636e35afe801464f2d1acecd3485c5'

api_key_zip_code = 'KN1FGI5C5GN1LSN3MIGB'

query_url = 'api.census.gov/data/2017/acs/acsse?get=NAME,K200001_001E&for=state:*&key=' + api_key_census

query_url2 = 'https://api.opendatanetwork.com/data/v1/map/new?app_token=cQovpGcdUT1CSzgYk0KPYdAI0&variable=jobs.earnings.median_earnings&entity_id=8600000US10019&year=2017'
response = requests.get(query_url2).json()
print(response)
print(json.dumps(response, indent = 4))
# Out:
# {'session_id': 'vlz3w10t33o435rn8x6jvpldi', 'bounds': [[40.758645, -74.003477], [40.772876, -73.973015]], 'summary_statistics': {'values': [-666666666, 20150, 24875, 27308, 30288, 32207, 36052, 41989, 233386], 'values_formatted': ['-$666,666,666', '$20,150', '$24,875', '$27,308', '$30,288', '$32,207', '$36,052', '$41,989', '$233,386'], 'names': ['minimum', '', 'lower quartile', '', 'median', '', 'upper quartile', '', 'maximum']}}
# {
#     "session_id": "vlz3w10t33o435rn8x6jvpldi",
#     "bounds": [
#         [
#             40.758645,
#             -74.003477
#         ],
#         [
#             40.772876,
#             -73.973015
#         ]
#     ],
#     "summary_statistics": {
#         "values": [
#             -666666666,
#             20150,
#             24875,
#             27308,
#             30288,
#             32207,
#             36052,
#             41989,
#             233386
#         ],
#         "values_formatted": [
#             "-$666,666,666",
# ...

# %%
response['summary_statistics']['values_formatted'][4]
# Out:
# '$30,288'

# %%
zip_query = 'https://www.zipcodeapi.com/rest/w65G93xpbTQ8I5HA07Oeew1PRPjLSaIL3ZOsv1yUQx36Gwxfcje4rFs4t55FHsnZ/city-zips.json/'
boroughs = ['Manhattan', 'Bronx', 'Brooklyn', 'Queens', 'Staten Island']
zip_code_list = []
zip_code_dict = {'Manhattan':{}, 'Bronx':{}, 'Brooklyn':{},  'Queens':{}, 'Staten Island':{}}
for borough in boroughs:
    zip_query2 = zip_query + borough + '/NY'
    response = requests.get(zip_query2)
    data = response.json()
    zip_code_dict[borough] = (data['zip_codes'])
zip_code_dict
# Out:
# {'Manhattan': ['10001',
#   '10002',
#   '10003',
#   '10005',
#   '10006',
#   '10007',
#   '10008',
#   '10009',
#   '10010',
#   '10012',
#   '10013',
#   '10014',
#   '10016',
#   '10017',
#   '10018',
#   '10019',
#   '10020',
#   '10021',
#   '10022',
#   '10023',
#   '10024',
#   '10025',
#   '10027',
#   '10028',
#   '10029',
#   '10030',
#   '10031',
#   '10032',
#   '10033',
#   '10034',
#   '10035',
#   '10036',
#   '10037',
#   '10038',
#   '10039',
#   '10040',
#   '10041',
#   '10048',
#   '10055',
#   '10101',
#   '10103',
#   '10104',
#   '10105',
#   '10106',
#   '10107',
#   '10108',
#   '10110',
#   '10111',
#   '10112',
#   '10113',
#   '10118',
#   '10119',
#   '10120',
#   '10121',
#   '10122',
#   '10123',
#   '10128',
#   '10150',
#   '10151',
#   '10152',
#   '10153',
#   '10154',
#   '10155',
#   '10158',
#   '10159',
#   '10162',
#   '10165',
#   '10166',
#   '10167',
#   '10168',
#   '10169',
#   '10170',
#   '10171',
#   '10172',
#   '10173',
# ...

# %%
# income_query_url_start = 'https://api.opendatanetwork.com/data/v1/map/new?app_token=cQovpGcdUT1CSzgYk0KPYdAI0&variable=jobs.earnings.median_earnings&entity_id=8600000US'
# income_query_url_end ='&year=2017'
# median_income_dict = {'Manhattan': {}, 'Bronx':{}, 'Brooklyn':{},  'Queens':{}, 'Staten Island':{}}
# for key in zip_code_dict:
#     for x in range(1):
#         income_query_url = income_query_url_start + zip_code_dict[key][x] + income_query_url_end
#         #print(income_query_url)
#         response2 = requests.get(income_query_url).json()
#         time.sleep(3)
#         #print(response2)
#         try:          
#             median_income_dict[key][zip_code_dict[key][x]] = response2['summary_statistics']['values_formatted'][4]
#             #print(response2['summary_statistics']['values_formatted'][4])
#         except KeyError:
#             print('Data not available')

# %%
# print(median_income_dict)

# %%
coord_query_url_beg = 'https://public.opendatasoft.com/api/records/1.0/search//?dataset=us-zip-code-latitude-and-longitude&q='
zip_coord_dict = {'Manhattan': {}, 'Bronx':{}, 'Brooklyn':{},  'Queens':{}, 'Staten Island':{}}

for key in zip_code_dict:
    for x in range(len(zip_code_dict[key])):
        coord_query_url = coord_query_url_beg + zip_code_dict[key][x]
        response3 = requests.get(coord_query_url)
        data2 = response3.json()
        try:
            #data2['records'][0]['fields']['longitude']
            zip_coord_dict[key][zip_code_dict[key][x]] = [data2['records'][0]['fields']['latitude'], data2['records'][0]['fields']['longitude']]
        except IndexError:
            print(f"Data not available {zip_code_dict[key][x]}")
# Out:
# Data not available 10200

# %%
zip_coord_dict
# Out:
# {'Manhattan': {'10001': [40.750742, -73.99653],
#   '10002': [40.71704, -73.987],
#   '10003': [40.732509, -73.98935],
#   '10005': [40.706019, -74.00858],
#   '10006': [40.707904, -74.01342],
#   '10007': [40.714754, -74.00721],
#   '10008': [40.780751, -73.977182],
#   '10009': [40.727092999999996, -73.97864],
#   '10010': [40.739022, -73.98205],
#   '10012': [40.72596, -73.99834],
#   '10013': [40.720666, -74.00526],
#   '10014': [40.734718, -74.00532],
#   '10016': [40.74618, -73.97759],
#   '10017': [40.752159, -73.97231],
#   '10018': [40.755101, -73.99337],
#   '10019': [40.765714, -73.9856],
#   '10020': [40.758667, -73.98024],
#   '10021': [40.76842, -73.96045],
#   '10022': [40.759015, -73.96732],
#   '10023': [40.776099, -73.98285],
#   '10024': [40.786387, -73.97709],
#   '10025': [40.798502, -73.96811],
#   '10027': [40.812665, -73.95499],
#   '10028': [40.776777, -73.9541],
#   '10029': [40.791586, -73.94575],
#   '10030': [40.818151, -73.94351],
# ...

# %%
df_Manhattan_coordinates = pd.DataFrame(zip_coord_dict['Manhattan']).T
df_Manhattan_coordinates
# Out:
#                0          1
# 10001  40.750742 -73.996530
# 10002  40.717040 -73.987000
# 10003  40.732509 -73.989350
# 10005  40.706019 -74.008580
# 10006  40.707904 -74.013420
# 10007  40.714754 -74.007210
# 10008  40.780751 -73.977182
# 10009  40.727093 -73.978640
# 10010  40.739022 -73.982050
# 10012  40.725960 -73.998340
# 10013  40.720666 -74.005260
# 10014  40.734718 -74.005320
# 10016  40.746180 -73.977590
# 10017  40.752159 -73.972310
# 10018  40.755101 -73.993370
# 10019  40.765714 -73.985600
# 10020  40.758667 -73.980240
# 10021  40.768420 -73.960450
# 10022  40.759015 -73.967320
# 10023  40.776099 -73.982850
# 10024  40.786387 -73.977090
# 10025  40.798502 -73.968110
# 10027  40.812665 -73.954990
# 10028  40.776777 -73.954100
# 10029  40.791586 -73.945750
# 10030  40.818151 -73.943510
# 10031  40.826201 -73.948790
# 10032  40.840686 -73.941540
# 10033  40.848764 -73.934960
# 10034  40.867653 -73.920000
# ...          ...        ...
# 10155  40.761104 -73.968036
# ...

# %%
df_Bronx_coordinates = pd.DataFrame(zip_coord_dict['Bronx']).T

df_Brooklyn_coordinates = pd.DataFrame(zip_coord_dict['Brooklyn']).T

df_Queens_coordinates = pd.DataFrame(zip_coord_dict['Queens']).T

df_StatenIsland_coordinates = pd.DataFrame(zip_coord_dict['Staten Island']).T

frames = [df_Manhattan_coordinates, df_Bronx_coordinates, df_Brooklyn_coordinates, df_Queens_coordinates, df_StatenIsland_coordinates]
dfNYC1 = pd.concat(frames)
dfNYC1.columns = ['Latitude', 'Longitude']
dfNYC1['Zip Code'] = dfNYC1.index
dfNYC1 = dfNYC1.reset_index(drop = True)
dfNYC1.head()
# Out:
#     Latitude  Longitude Zip Code
# 0  40.750742  -73.99653    10001
# 1  40.717040  -73.98700    10002
# 2  40.732509  -73.98935    10003
# 3  40.706019  -74.00858    10005
# 4  40.707904  -74.01342    10006

# %%
newresponse = requests.get('https://www.incomebyzipcode.com/newyork/10012')
newresponse.content
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n  <!-- Global site tag (gtag.js) - Google Analytics -->\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-68653-9"></script>\n<script>\n  window.dataLayer = window.dataLayer || [];\n  function gtag(){dataLayer.push(arguments);}\n  gtag(\'js\', new Date());\n\n  gtag(\'config\', \'UA-68653-9\');\n  gtag(\'config\', \'AW-1035998641\');\n</script>\n\n\n  <title>10012 Income Statistics - Current Census Data for Zip Codes</title>\n  <meta charset="utf-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n\n  <meta name=\'description\' content=\'Get the most current US Census income data for zip code 10012. Compare 10012 income statistics with data for neighboring New York zip codes, counties and cities.\'>\n  <link rel="canonical" href="https://www.incomebyzipcode.com/newyork/10012">\n  <link rel="stylesheet" media="all" href="https://d3u7142ylbwtzx.cloudfront.net/assets/application-f9b474874e198d
# ...

# %%
soup = bs(newresponse.content, 'html.parser')
#print(soup.prettify())

# %%
list(soup.children)

# %%
[type(item) for item in list(soup.children)]

# %%
info = soup.find(id = "container mt-5 px-3 px-md-0")
#print(info)
mydivs = soup.find("td", {"class": "hilite"})
#print(mydivs.get_text())

# %%
income_url_beg = 'https://www.incomebyzipcode.com/newyork/'

income_dict = {'Manhattan': {}, 'Bronx':{}, 'Brooklyn':{},  'Queens':{}, 'Staten Island':{}}

for key in zip_code_dict:
    for x in range(len(zip_code_dict[key])):
        income_url = income_url_beg + zip_code_dict[key][x]
        #print(income_url)
        newresponse2 = requests.get(income_url)
        soup2 = bs(newresponse2.content, 'html.parser')
        #print(soup2)
        info = soup2.find(id = "container mt-5 px-3 px-md-0")
        mydiv = soup2.find("td", {"class": "hilite"})
        #print(mydiv)
        try:
            income_dict[key][zip_code_dict[key][x]] = mydiv.get_text()
        except AttributeError: 
            print(f'No data for {zip_code_dict[key][x]}')
        #print(mydiv.get_text())
# Out:
# No data for 10008
# No data for 10041
# No data for 10048
# No data for 10055
# No data for 10101
# No data for 10104
# No data for 10105
# No data for 10106
# No data for 10107
# No data for 10108
# No data for 10113
# No data for 10118
# No data for 10120
# No data for 10121
# No data for 10122
# No data for 10123
# No data for 10150
# No data for 10151
# No data for 10155
# No data for 10158
# No data for 10159
# No data for 10166
# No data for 10175
# No data for 10176
# No data for 10178
# No data for 10200
# No data for 10249
# No data for 10256
# No data for 10268
# No data for 10270
# No data for 10276
# No data for 10281
# No data for 10286
# No data for 10499
# No data for 11202
# No data for 11240
# No data for 11241
# No data for 11242
# No data for 11243
# No data for 11244
# No data for 11245
# No data for 11247
# No data for 11248
# No data for 11249
# No data for 11251
# No data for 11252
# No data for 11254
# No data for 11255
# No data for 11256
# No data for 11120
# ...

# %%
income_dict

# %%
dfManhattan = pd.DataFrame(income_dict['Manhattan'], index=[0]).T
dfManhattan.head()
# Out:
#               0
# 10001   $85,221
# 10002   $35,449
# 10003  $104,441
# 10005  $154,213
# 10006  $145,893

# %%
dfBronx = pd.DataFrame(income_dict['Bronx'], index=[0]).T
dfBronx.head()
# Out:
#              0
# 10451  $26,979
# 10452  $27,206
# 10453  $24,421
# 10454  $21,542
# 10455  $25,489

# %%
dfBrooklyn = pd.DataFrame(income_dict['Brooklyn'], index=[0]).T

# %%
dfQueens = pd.DataFrame(income_dict['Queens'], index=[0]).T
#dfQueens.head()

# %%
dfStatenIsland = pd.DataFrame(income_dict['Staten Island'], index=[0]).T
#dfStatenIsland.head()

# %%
frames = [dfManhattan, dfBronx, dfBrooklyn, dfQueens, dfStatenIsland]
dfNYC2 = pd.concat(frames)
dfNYC2.columns = ['Median Household Income']

# %%
dfNYC2.head()

# %%
indexNames = dfNYC2[dfNYC2['Median Household Income'] == '$0'].index
 
# Delete these row indexes from dataFrame
dfNYC2.drop(indexNames , inplace=True)

# %%
dfNYC2.head()

# %%
dfNYC2['Zip Code'] = dfNYC2.index

# %%
dfNYC2 = dfNYC2.reset_index(drop = True)
#dfNYC2.head()

# %%
dfNYC = pd.merge(dfNYC1, dfNYC2, on = 'Zip Code')
#dfNYC.head()

# %%
gmaps.configure(api_key = 'AIzaSyBPGiM9DukiiU_NR_q5j1y7DM43rtOOyTs')

# %%
dfNYC['Median Household Income'] = dfNYC['Median Household Income'].map(lambda x: x.lstrip('$').rstrip('aAbBcC'))

locale.setlocale( locale.LC_ALL, 'en_US.UTF-8' ) 
for x in range(len(dfNYC['Median Household Income'])):
    dfNYC.iloc[x, 3] = locale.atoi(dfNYC.iloc[x, 3])

# %%
locations = dfNYC[['Latitude','Longitude']].astype(float)
med_inc = dfNYC['Median Household Income'].astype(float)

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights= med_inc, 
                                 dissipating=False, max_intensity=180000,
                                 point_radius = 0.03)

fig.add_layer(heat_layer)

fig

# %%
# Run Census Search to retrieve data on all zip codes (2013 ACS5 Census)
# See: https://github.com/CommerceDataService/census-wrapper for library documentation
# See: https://gist.github.com/afhaque/60558290d6efd892351c4b64e5c01e9b for labels
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E","B23025_005E", "B23025_003E", "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B23025_005E": "Unemployed Labor Force",
                                      "B23025_003E": "Labor Force",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zip Code"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = 100 * \
    census_pd["Poverty Count"].astype(
        int) / census_pd["Population"].astype(int)
census_pd["Unemployment Rate"] = 100 * (census_pd['Unemployed Labor Force'].astype(int)/census_pd['Labor Force'].astype(int))

# Final DataFrame
census_pd = census_pd[["Zip Code", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Unemployment Rate", "Poverty Count", "Poverty Rate"]]

# Visualize
# print(len(census_pd))
# census_pd.head()
df_big = dfNYC.merge(census_pd, how = 'left', on = 'Zip Code')
df_big.head()
# Out:
#     Latitude  Longitude Zip Code  Median Household Income  Population  \
# 0  40.750742  -73.99653    10001                    85221     23947.0
# 1  40.717040  -73.98700    10002                    35449     77925.0
# 2  40.732509  -73.98935    10003                   104441     55035.0
# 3  40.706019  -74.00858    10005                   154213      8680.0
# 4  40.707904  -74.01342    10006                   145893      3579.0
#
#    Median Age  Household Income  Per Capita Income  Unemployment Rate  \
# 0        35.3           85221.0            86014.0           6.188135
# 1        41.8           35449.0            30677.0           8.285599
# 2        32.6          104441.0            91141.0           4.877486
# 3        30.2          154213.0           102957.0           2.664375
# 4        30.7          145893.0           103279.0           1.663586
#
#    Poverty Count  Poverty Rate
# 0         4211.0     17.584666
# 1        21214.0     27.223612
# ...

# %%
df_big.to_csv('df_big.csv')

# %%
locations = df_big[['Latitude','Longitude']].astype(float)
pop_weights = df_big['Population'].astype(float)

# %%
fig4 = gmaps.figure()

heat_layer4 = gmaps.heatmap_layer(locations, weights= pop_weights, 
                                 dissipating=False, max_intensity=350000,
                                 point_radius = 0.04)

fig4.add_layer(heat_layer4)

fig4
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
locations = df_big[['Latitude','Longitude']].astype(float)
UR_weights = df_big['Unemployment Rate'].astype(float)

# %%
fig2 = gmaps.figure()

heat_layer2 = gmaps.heatmap_layer(locations, weights= UR_weights, 
                                 dissipating=False, max_intensity=45,
                                 point_radius = 0.04)

fig2.add_layer(heat_layer2)

fig2

# %%
locations = df_big[['Latitude','Longitude']].astype(float)
PR_weights = df_big['Poverty Rate'].astype(float)

# %%
fig3 = gmaps.figure()

heat_layer3 = gmaps.heatmap_layer(locations, weights= PR_weights, 
                                 dissipating=False, max_intensity=130,
                                 point_radius = 0.04)

fig3.add_layer(heat_layer3)

fig3

# %%
# Dependencies
import random
from uszipcode import SearchEngine
search = SearchEngine(simple_zipcode=True)
#api_key

# %%
file='NYPD_Data.csv'
df_Pam=pd.read_csv(file)
df_Pam.head()
# convert CMPLNT_FR_DT to date format. 222398 rows records in file
df_Pam['CMPLNT_FR_DT'] = pd.to_datetime(df_Pam['CMPLNT_FR_DT'],errors = 'coerce') 
#df_Pam.head()

# %%
# Filter for only "Felony" category
felonyDf = df_Pam[df_Pam["LAW_CAT_CD"] == 'FELONY'] 
felonyDf=felonyDf.reset_index(drop=True)
# Drop rows if CMPLNT_FR_DT does not have any value
felonyDf=felonyDf.dropna(subset = ['CMPLNT_FR_DT'])
# Limit our analysis to last 10 years - 2010 to 2019
felonyDf = felonyDf[(felonyDf['CMPLNT_FR_DT'] > '2010-01-01') & (felonyDf['CMPLNT_FR_DT'] <= '2019-09-06')]
# create new columns to store year and month to enable aggregration
felonyDf['CMPLNT_YR']=pd.DatetimeIndex(felonyDf['CMPLNT_FR_DT']).year
felonyDf['CMPLNT_Month']=pd.DatetimeIndex(felonyDf['CMPLNT_FR_DT']).month
#felonyDf.to_csv('felonyfull.csv')

#felonyDf.head()

# %%
zip_code_series = pd.Series()
zips = []
for x in range(len(felonyDf['Latitude'])):
    zipcode = search.by_coordinates(felonyDf.iloc[x,-5].astype(float), felonyDf.iloc[x, -4].astype(float), radius=1, returns=1)
    try:
        zipcode = zipcode[0].to_dict()
        zips.append(zipcode['zipcode'])
        #print(zips)
    except IndexError:
        #print('Data not Found')
        zips.append(0)
